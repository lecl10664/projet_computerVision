# %% [markdown]
# # Step A - Multiple Product Detection
#
# Test on scene image: {e1.png, e2.png, e3.png, e4.png, e5.png}
# Use product images: {0.jpg, 1.jpg, 11.jpg, 19.jpg, 24.jpg, 26.jpg, 25.jpg}

# %% [markdown]
# Develop an object detection system to identify single instance of products given: one reference image for each item and a scene image. The system should be able to correctly identify all the product in the shelves image. One way to solve this task could be the use of local invariant feature as explained in lab session 5.

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img1 = cv2.imread('models/0.jpg', cv2.IMREAD_GRAYSCALE) #queryImage
print("Shape Image1 :", image1.shape)
img2 = cv2.imread('scenes/e1.png', cv2.IMREAD_GRAYSCALE) #trainImage
print("Saphe Image2 :",image2.shape)
# Out:
# Shape Image1 : (1500, 1105, 3)
# Saphe Image2 : (458, 627, 3)

# %%
plt.imshow(image1)
plt.show()

# %%
plt.imshow(image2)
plt.show()

# %% [markdown]
# ### Brute-Force Matching with ORB Descriptors

# %%
# Initiate ORB detector
orb = cv2.ORB_create()

# find the keypoints and descriptors with ORB
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
des1
# Out:
# array([[ 55, 229,  66, ..., 191, 251, 148],
#        [ 24, 177, 122, ..., 130, 166, 251],
#        [120,  44, 186, ...,  66, 230, 170],
#        ...,
#        [ 95,  49, 254, ..., 134, 173,  86],
#        [ 35, 243,  32, ..., 222, 220, 221],
#        [ 32, 186, 247, ...,  40,  87, 169]], dtype=uint8)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# %%
# Match descriptors.
matches = bf.match(des1,des2)

# %%
matches
# Out:
# [<DMatch 0x7faaf4ccfbf0>,
#  <DMatch 0x7faaf4ecb2f0>,
#  <DMatch 0x7faaf4ecb550>,
#  <DMatch 0x7faaf4ecb570>,
#  <DMatch 0x7faaf4ecbc70>,
#  <DMatch 0x7faaf4ecb770>,
#  <DMatch 0x7faaf4ecbf30>,
#  <DMatch 0x7faaf4ecb5b0>,
#  <DMatch 0x7faaf4ecb730>,
#  <DMatch 0x7faaf4ecbaf0>,
#  <DMatch 0x7faaf4ecbbd0>,
#  <DMatch 0x7faaf4ecb630>,
#  <DMatch 0x7faaf4ecb5d0>,
#  <DMatch 0x7faaf4ecbb70>,
#  <DMatch 0x7faaf4ecb7d0>,
#  <DMatch 0x7faaf4ecb790>,
#  <DMatch 0x7faaf4ecbe90>,
#  <DMatch 0x7faaf4ecb130>,
#  <DMatch 0x7faaf4ecbbb0>,
#  <DMatch 0x7faaf5dd5eb0>,
#  <DMatch 0x7faaf301dab0>,
#  <DMatch 0x7faaf301d190>,
#  <DMatch 0x7faaf301dbb0>,
#  <DMatch 0x7faaf5f5e890>,
#  <DMatch 0x7faaf5f5e130>,
#  <DMatch 0x7faaf5f5e790>,
#  <DMatch 0x7faaf5f5e870>,
#  <DMatch 0x7faaf5f5ee10>,
#  <DMatch 0x7faaf5f5e2f0>,
#  <DMatch 0x7faaf5f5ec30>,
#  <DMatch 0x7faaf5f5e990>,
#  <DMatch 0x7faaf5f5ee70>,
#  <DMatch 0x7faaf32e0130>,
#  <DMatch 0x7faaf32e0150>,
#  <DMatch 0x7faaf32e0170>,
#  <DMatch 0x7faaf32e0ab0>,
#  <DMatch 0x7faaf32e0ad0>,
#  <DMatch 0x7faaf32e0af0>,
#  <DMatch 0x7faaf32e0b10>,
#  <DMatch 0x7faaf32e0b30>,
#  <DMatch 0x7faaf32e0b50>,
#  <DMatch 0x7faaf32e0b70>,
#  <DMatch 0x7faaf32e0b90>,
#  <DMatch 0x7faaf32e0bb0>,
#  <DMatch 0x7faaf32e0bd0>,
#  <DMatch 0x7faaf32e0bf0>,
#  <DMatch 0x7faaf32e0c10>,
#  <DMatch 0x7faaf32e0c30>,
#  <DMatch 0x7faaf32e0c50>,
#  <DMatch 0x7faaf32e0c70>,
#  <DMatch 0x7faaf32e0c90>,
#  <DMatch 0x7faaf32e0cb0>,
#  <DMatch 0x7faaf32e0cd0>,
#  <DMatch 0x7faaf32e0cf0>,
#  <DMatch 0x7faaf32e0d10>,
#  <DMatch 0x7faaf32e0d30>,
#  <DMatch 0x7faaf32e0d50>,
#  <DMatch 0x7faaf32e0d70>,
#  <DMatch 0x7faaf32e0d90>,
#  <DMatch 0x7faaf32e0db0>,
#  <DMatch 0x7faaf32e0dd0>,
#  <DMatch 0x7faaf32e0df0>,
#  <DMatch 0x7faaf32e0e10>,
#  <DMatch 0x7faaf32e0e30>,
#  <DMatch 0x7faaf32e0e50>,
#  <DMatch 0x7faaf32e0e70>,
#  <DMatch 0x7faaf32e0e90>,
#  <DMatch 0x7faaf32e0eb0>,
#  <DMatch 0x7faaf32e0ed0>,
#  <DMatch 0x7faaf32e0ef0>,
#  <DMatch 0x7faaf32e0f10>,
#  <DMatch 0x7faaf32e0f30>,
#  <DMatch 0x7faaf32e0f50>,
#  <DMatch 0x7faaf32e0f70>,
#  <DMatch 0x7faaf32e0f90>,
#  <DMatch 0x7faaf32e0fb0>]

# %%
# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# %%
# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:10],None,flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

plt.figure( figsize=(10,10))
plt.imshow(img3)
plt.show()

# %% [markdown]
# ### Brute-Force Matching with SIFT Descriptors and Ratio Test

# %%
# Initiate SIFT detector
sift = cv2.SIFT_create()

# %%
# Find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)

# %%
# BFMatcher with default params
bf = cv2.BFMatcher()
matches = bf.knnMatch(des1,des2,k=2)

# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
        
# cv.drawMatchesKnn expects list of lists as matches.
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

plt.figure(figsize=(10,10))
plt.imshow(img3)
plt.show()

# %%
matches[0][1].distance
# Out:
# 291.50299072265625

# %% [markdown]
# ---------

# %%
image = cv2.imread('scenes/e1.png')
image.shape
# Out:
# (458, 627, 3)

# %%
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)

# %%
points = np.array([[0,0],[0,450],[300,450], [300,0]])
points
# Out:
# array([[  0,   0],
#        [  0, 450],
#        [300, 450],
#        [300,   0]])

# %%
  
# Using cv2.polylines() method
imagewithdraw = cv2.polylines(image_rgb, [points], 
                      isClosed=True, color=(0,255,0), thickness=4)
plt.imshow(imagewithdraw)
plt.show()
